# %%
import sys
sys.path.insert(0, r'E:\GitHub\molass-library')
from molass.Local import get_local_settings
local_settings = get_local_settings()
TUTORIAL_DATA = local_settings['TUTORIAL_DATA']
print(TUTORIAL_DATA)
from molass.Global.Options import set_molass_options
set_molass_options(flowchange=True)
# Out:
# E:\MolassData\tutorial_data

# %% [markdown]
# # Data Correction
# ## Study Points
# * ssd.corrected_copy()

# %%
from molass.DataObjects import SecSaxsData as SSD
ssd = SSD(TUTORIAL_DATA)
ssd.plot_3d();

# %%
ssd.plot_trimming_info();

# %%
trimmed_ssd = ssd.trimmed_copy()

# %%
plot = trimmed_ssd.plot_3d(view_init=dict(elev=20, azim=-30), view_arrows=True)

# %%
# plot.fig.savefig('corrected_ssd_3d.png')
